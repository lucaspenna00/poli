# %%
#resnet_hae3.py - testado em Colab com TF2
import keras
from keras.datasets import cifar10
from keras.models import Model
from keras.models import load_model
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import GlobalAveragePooling2D, Input, Flatten
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.activations import relu
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
from inspect import currentframe, getframeinfo
import os
import sys
from keras.callbacks import LearningRateScheduler


batch_size = 32; num_classes = 10; epochs = 200
nl, nc = 32,32
(ax, ay), (qx, qy) = cifar10.load_data()
ax = ax.reshape(ax.shape[0], nl, nc, 3)
qx = qx.reshape(qx.shape[0], nl, nc, 3)
input_shape = (nl, nc, 3)
ax = ax.astype('float32')
qx = qx.astype('float32')
ax /= 255 #0 a 1
qx /= 255 #0 a 1
ax -= 0.5 #-0.5 a +0.5
qx -= 0.5 #-0.5 a +0.5
ay = keras.utils.to_categorical(ay, num_classes)
qy = keras.utils.to_categorical(qy, num_classes)

model = load_model("resnet_hae3.h5")

from keras.utils import plot_model

plot_model(model, to_file=nomeprog+'.png', show_shapes=True)

model.summary()
# Out:
# Model: "functional_45"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_24 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_393 (Conv2D)             (None, 32, 32, 16)   448         input_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_355 (BatchN (None, 32, 32, 16)   64          conv2d_393[0][0]
# __________________________________________________________________________________________________
# activation_355 (Activation)     (None, 32, 32, 16)   0           batch_normalization_355[0][0]
# __________________________________________________________________________________________________
# conv2d_394 (Conv2D)             (None, 32, 32, 16)   2320        activation_355[0][0]
# __________________________________________________________________________________________________
# batch_normalization_356 (BatchN (None, 32, 32, 16)   64          conv2d_394[0][0]
# __________________________________________________________________________________________________
# activation_356 (Activation)     (None, 32, 32, 16)   0           batch_normalization_356[0][0]
# __________________________________________________________________________________________________
# conv2d_395 (Conv2D)             (None, 32, 32, 16)   2320        activation_356[0][0]
# __________________________________________________________________________________________________
# batch_normalization_357 (BatchN (None, 32, 32, 16)   64          conv2d_395[0][0]
# __________________________________________________________________________________________________
# add_158 (Add)                   (None, 32, 32, 16)   0           activation_355[0][0]
#                                                                  batch_normalization_357[0][0]
# __________________________________________________________________________________________________
# activation_357 (Activation)     (None, 32, 32, 16)   0           add_158[0][0]
# __________________________________________________________________________________________________
# conv2d_396 (Conv2D)             (None, 32, 32, 16)   2320        activation_357[0][0]
# __________________________________________________________________________________________________
# batch_normalization_358 (BatchN (None, 32, 32, 16)   64          conv2d_396[0][0]
# __________________________________________________________________________________________________
# activation_358 (Activation)     (None, 32, 32, 16)   0           batch_normalization_358[0][0]
# __________________________________________________________________________________________________
# conv2d_397 (Conv2D)             (None, 32, 32, 16)   2320        activation_358[0][0]
# __________________________________________________________________________________________________
# batch_normalization_359 (BatchN (None, 32, 32, 16)   64          conv2d_397[0][0]
# __________________________________________________________________________________________________
# add_159 (Add)                   (None, 32, 32, 16)   0           activation_357[0][0]
#                                                                  batch_normalization_359[0][0]
# __________________________________________________________________________________________________
# activation_359 (Activation)     (None, 32, 32, 16)   0           add_159[0][0]
# __________________________________________________________________________________________________
# conv2d_398 (Conv2D)             (None, 32, 32, 16)   2320        activation_359[0][0]
# __________________________________________________________________________________________________
# batch_normalization_360 (BatchN (None, 32, 32, 16)   64          conv2d_398[0][0]
# __________________________________________________________________________________________________
# activation_360 (Activation)     (None, 32, 32, 16)   0           batch_normalization_360[0][0]
# __________________________________________________________________________________________________
# conv2d_399 (Conv2D)             (None, 32, 32, 16)   2320        activation_360[0][0]
# __________________________________________________________________________________________________
# batch_normalization_361 (BatchN (None, 32, 32, 16)   64          conv2d_399[0][0]
# __________________________________________________________________________________________________
# add_160 (Add)                   (None, 32, 32, 16)   0           activation_359[0][0]
#                                                                  batch_normalization_361[0][0]
# __________________________________________________________________________________________________
# activation_361 (Activation)     (None, 32, 32, 16)   0           add_160[0][0]
# __________________________________________________________________________________________________
# conv2d_400 (Conv2D)             (None, 16, 16, 32)   4640        activation_361[0][0]
# __________________________________________________________________________________________________
# batch_normalization_362 (BatchN (None, 16, 16, 32)   128         conv2d_400[0][0]
# __________________________________________________________________________________________________
# activation_362 (Activation)     (None, 16, 16, 32)   0           batch_normalization_362[0][0]
# __________________________________________________________________________________________________
# conv2d_401 (Conv2D)             (None, 16, 16, 32)   9248        activation_362[0][0]
# __________________________________________________________________________________________________
# conv2d_402 (Conv2D)             (None, 16, 16, 32)   544         activation_361[0][0]
# __________________________________________________________________________________________________
# batch_normalization_363 (BatchN (None, 16, 16, 32)   128         conv2d_401[0][0]
# __________________________________________________________________________________________________
# add_161 (Add)                   (None, 16, 16, 32)   0           conv2d_402[0][0]
#                                                                  batch_normalization_363[0][0]
# __________________________________________________________________________________________________
# activation_363 (Activation)     (None, 16, 16, 32)   0           add_161[0][0]
# __________________________________________________________________________________________________
# conv2d_403 (Conv2D)             (None, 16, 16, 32)   9248        activation_363[0][0]
# __________________________________________________________________________________________________
# batch_normalization_364 (BatchN (None, 16, 16, 32)   128         conv2d_403[0][0]
# __________________________________________________________________________________________________
# activation_364 (Activation)     (None, 16, 16, 32)   0           batch_normalization_364[0][0]
# __________________________________________________________________________________________________
# conv2d_404 (Conv2D)             (None, 16, 16, 32)   9248        activation_364[0][0]
# __________________________________________________________________________________________________
# batch_normalization_365 (BatchN (None, 16, 16, 32)   128         conv2d_404[0][0]
# __________________________________________________________________________________________________
# add_162 (Add)                   (None, 16, 16, 32)   0           activation_363[0][0]
#                                                                  batch_normalization_365[0][0]
# __________________________________________________________________________________________________
# activation_365 (Activation)     (None, 16, 16, 32)   0           add_162[0][0]
# __________________________________________________________________________________________________
# conv2d_405 (Conv2D)             (None, 16, 16, 32)   9248        activation_365[0][0]
# __________________________________________________________________________________________________
# batch_normalization_366 (BatchN (None, 16, 16, 32)   128         conv2d_405[0][0]
# __________________________________________________________________________________________________
# activation_366 (Activation)     (None, 16, 16, 32)   0           batch_normalization_366[0][0]
# __________________________________________________________________________________________________
# conv2d_406 (Conv2D)             (None, 16, 16, 32)   9248        activation_366[0][0]
# __________________________________________________________________________________________________
# batch_normalization_367 (BatchN (None, 16, 16, 32)   128         conv2d_406[0][0]
# __________________________________________________________________________________________________
# add_163 (Add)                   (None, 16, 16, 32)   0           activation_365[0][0]
#                                                                  batch_normalization_367[0][0]
# __________________________________________________________________________________________________
# activation_367 (Activation)     (None, 16, 16, 32)   0           add_163[0][0]
# __________________________________________________________________________________________________
# conv2d_407 (Conv2D)             (None, 8, 8, 64)     18496       activation_367[0][0]
# __________________________________________________________________________________________________
# batch_normalization_368 (BatchN (None, 8, 8, 64)     256         conv2d_407[0][0]
# __________________________________________________________________________________________________
# activation_368 (Activation)     (None, 8, 8, 64)     0           batch_normalization_368[0][0]
# __________________________________________________________________________________________________
# conv2d_408 (Conv2D)             (None, 8, 8, 64)     36928       activation_368[0][0]
# __________________________________________________________________________________________________
# conv2d_409 (Conv2D)             (None, 8, 8, 64)     2112        activation_367[0][0]
# __________________________________________________________________________________________________
# batch_normalization_369 (BatchN (None, 8, 8, 64)     256         conv2d_408[0][0]
# __________________________________________________________________________________________________
# add_164 (Add)                   (None, 8, 8, 64)     0           conv2d_409[0][0]
#                                                                  batch_normalization_369[0][0]
# __________________________________________________________________________________________________
# activation_369 (Activation)     (None, 8, 8, 64)     0           add_164[0][0]
# __________________________________________________________________________________________________
# conv2d_410 (Conv2D)             (None, 8, 8, 64)     36928       activation_369[0][0]
# __________________________________________________________________________________________________
# batch_normalization_370 (BatchN (None, 8, 8, 64)     256         conv2d_410[0][0]
# __________________________________________________________________________________________________
# activation_370 (Activation)     (None, 8, 8, 64)     0           batch_normalization_370[0][0]
# __________________________________________________________________________________________________
# conv2d_411 (Conv2D)             (None, 8, 8, 64)     36928       activation_370[0][0]
# __________________________________________________________________________________________________
# batch_normalization_371 (BatchN (None, 8, 8, 64)     256         conv2d_411[0][0]
# __________________________________________________________________________________________________
# add_165 (Add)                   (None, 8, 8, 64)     0           activation_369[0][0]
#                                                                  batch_normalization_371[0][0]
# __________________________________________________________________________________________________
# activation_371 (Activation)     (None, 8, 8, 64)     0           add_165[0][0]
# __________________________________________________________________________________________________
# conv2d_412 (Conv2D)             (None, 8, 8, 64)     36928       activation_371[0][0]
# __________________________________________________________________________________________________
# batch_normalization_372 (BatchN (None, 8, 8, 64)     256         conv2d_412[0][0]
# __________________________________________________________________________________________________
# activation_372 (Activation)     (None, 8, 8, 64)     0           batch_normalization_372[0][0]
# __________________________________________________________________________________________________
# conv2d_413 (Conv2D)             (None, 8, 8, 64)     36928       activation_372[0][0]
# __________________________________________________________________________________________________
# batch_normalization_373 (BatchN (None, 8, 8, 64)     256         conv2d_413[0][0]
# __________________________________________________________________________________________________
# add_166 (Add)                   (None, 8, 8, 64)     0           activation_371[0][0]
#                                                                  batch_normalization_373[0][0]
# __________________________________________________________________________________________________
# activation_373 (Activation)     (None, 8, 8, 64)     0           add_166[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 64)           0           activation_373[0][0]
# __________________________________________________________________________________________________
# flatten_22 (Flatten)            (None, 64)           0           global_average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 10)           650         flatten_22[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# Test loss: 0.42604175209999084
# Test accuracy: 0.9186999797821045

# %%
dados = []

for n in range(0, 10000):
    
    

    datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, fill_mode='nearest', horizontal_flip=True)
    datagen.fit(qx)
    dados.append(qx)

# %%
score = model.evaluate(qx, qy, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
dados[0]
# Out:
# array([[[[ 0.11960787, -0.06078431, -0.30784315],
#          [ 0.12352943, -0.06470588, -0.3156863 ],
#          [ 0.14705884, -0.04509804, -0.3       ],
#          ...,
#          [ 0.03725493, -0.12745097, -0.35882354],
#          [-0.00588235, -0.14313725, -0.35882354],
#          [-0.04509804, -0.16666666, -0.37058824]],
#
#         [[ 0.09607846, -0.06078431, -0.3       ],
#          [ 0.09215689, -0.06862745, -0.34313726],
#          [ 0.12352943, -0.05294117, -0.32352942],
#          ...,
#          [ 0.03333336, -0.12745097, -0.37843138],
#          [-0.00980392, -0.14313725, -0.3745098 ],
#          [-0.03333333, -0.15490195, -0.36666667]],
#
#         [[ 0.09215689, -0.06862745, -0.3156863 ],
#          [ 0.09215689, -0.07254902, -0.37058824],
#          [ 0.11960787, -0.06470588, -0.35882354],
#          ...,
#          [ 0.04509807, -0.11568627, -0.36666667],
#          [ 0.00980395, -0.12745097, -0.36666667],
#          [-0.02941176, -0.15098038, -0.37058824]],
#
#         ...,
#
#         [[-0.23333332, -0.01372549,  0.19411767],
#          [-0.33529413, -0.10784313,  0.08039218],
#          [-0.37843138, -0.15490195,  0.03725493],
#          ...,
#          [-0.3509804 , -0.11960784,  0.07254905],
#          [-0.4490196 , -0.2490196 , -0.07647058],
#          [-0.34313726, -0.16666666, -0.00196078]],
#
#         [[-0.26078433, -0.04509804,  0.15882355],
#          [-0.30784315, -0.09999999,  0.08039218],
#          [-0.3627451 , -0.16666666,  0.01764709],
#          ...,
#          [-0.39803922, -0.17843136,  0.00980395],
#          [-0.38627452, -0.17843136, -0.00588235],
#          [-0.42156863, -0.2490196 , -0.08039215]],
#
#         [[-0.2882353 , -0.08039215,  0.127451  ],
#          [-0.28039217, -0.08823529,  0.08431375],
#          [-0.32352942, -0.15098038,  0.01764709],
#          ...,
#          [-0.40588236, -0.1980392 , -0.01372549],
#          [-0.36666667, -0.17058823,  0.00588238],
#          [-0.41764706, -0.23725489, -0.06862745]]],
#
#
#        [[[ 0.42156863,  0.42156863,  0.42156863],
#          [ 0.40588236,  0.40588236,  0.40588236],
#          [ 0.40980393,  0.40980393,  0.40980393],
#          ...,
#          [ 0.4137255 ,  0.4137255 ,  0.4137255 ],
#          [ 0.4137255 ,  0.4137255 ,  0.4137255 ],
#          [ 0.40980393,  0.40980393,  0.40980393]],
#
#         [[ 0.43333334,  0.43333334,  0.43333334],
#          [ 0.42156863,  0.42156863,  0.42156863],
#          [ 0.42156863,  0.42156863,  0.42156863],
#          ...,
#          [ 0.4254902 ,  0.4254902 ,  0.4254902 ],
#          [ 0.4254902 ,  0.4254902 ,  0.4254902 ],
#          [ 0.42156863,  0.42156863,  0.42156863]],
#
#         [[ 0.42941177,  0.42941177,  0.42941177],
#          [ 0.41764706,  0.41764706,  0.41764706],
#          [ 0.41764706,  0.41764706,  0.41764706],
#          ...,
#          [ 0.42156863,  0.42156863,  0.42156863],
#          [ 0.42156863,  0.42156863,  0.42156863],
#          [ 0.41764706,  0.41764706,  0.41764706]],
#
#         ...,
#
#         [[-0.15882352, -0.1117647 , -0.15098038],
#          [-0.33137256, -0.3       , -0.35490197],
#          [-0.4254902 , -0.40980393, -0.45686275],
#          ...,
#          [ 0.16274512,  0.22156864,  0.2019608 ],
#          [ 0.2137255 ,  0.27254903,  0.25686276],
#          [ 0.23725492,  0.29215688,  0.2882353 ]],
#
#         [[-0.17843136, -0.1235294 , -0.17843136],
#          [-0.31960785, -0.2764706 , -0.35882354],
#          [-0.35882354, -0.327451  , -0.4137255 ],
#          ...,
#          [ 0.18235296,  0.24117649,  0.21764708],
#          [ 0.22549021,  0.28431374,  0.26862746],
#          [ 0.23333335,  0.29215688,  0.28431374]],
#
#         [[-0.16666666, -0.10392156, -0.1745098 ],
#          [-0.25686276, -0.20588234, -0.31176472],
#          [-0.27254903, -0.23725489, -0.3509804 ],
#          ...,
#          [ 0.15882355,  0.21764708,  0.19803923],
#          [ 0.20588237,  0.2647059 ,  0.24901962],
#          [ 0.22941178,  0.28431374,  0.28039217]]],
#
#
#        [[[ 0.11960787,  0.24509805,  0.37058824],
#          [ 0.11960787,  0.23333335,  0.35490197],
#          [ 0.04509807,  0.15098041,  0.26078433],
#          ...,
#          [ 0.39411765,  0.40588236,  0.41764706],
#          [ 0.42941177,  0.4372549 ,  0.45294118],
#          [ 0.43333334,  0.44509804,  0.46470588]],
#
#         [[ 0.16666669,  0.28431374,  0.39803922],
#          [ 0.17450982,  0.28039217,  0.38627452],
#          [ 0.09215689,  0.1901961 ,  0.2882353 ],
#          ...,
#          [ 0.40980393,  0.40980393,  0.4254902 ],
#          [ 0.46470588,  0.46470588,  0.48039216],
#          [ 0.46470588,  0.46862745,  0.48431373]],
#
#         [[ 0.18235296,  0.2882353 ,  0.38235295],
#          [ 0.1901961 ,  0.28431374,  0.37058824],
#          [ 0.1156863 ,  0.2019608 ,  0.28039217],
#          ...,
#          [ 0.4019608 ,  0.39803922,  0.40980393],
#          [ 0.48039216,  0.4764706 ,  0.48431373],
#          [ 0.46078432,  0.45686275,  0.46862745]],
#
#         ...,
#
#         [[-0.37843138, -0.34313726, -0.32352942],
#          [-0.38235295, -0.34705883, -0.327451  ],
#          [-0.39803922, -0.3627451 , -0.34313726],
#          ...,
#          [-0.35490197, -0.34313726, -0.31960785],
#          [-0.46470588, -0.4490196 , -0.44509804],
#          [-0.48431373, -0.47254902, -0.48039216]],
#
#         [[-0.40980393, -0.36666667, -0.34705883],
#          [-0.39411765, -0.3509804 , -0.33137256],
#          [-0.4019608 , -0.35882354, -0.3392157 ],
#          ...,
#          [-0.4254902 , -0.42156863, -0.40588236],
#          [-0.48431373, -0.4764706 , -0.4882353 ],
#          [-0.48039216, -0.47254902, -0.4882353 ]],
#
#         [[-0.39019608, -0.3392157 , -0.3156863 ],
#          [-0.38235295, -0.33137256, -0.30392158],
#          [-0.3745098 , -0.32352942, -0.29607844],
#          ...,
#          [-0.48039216, -0.4764706 , -0.46862745],
#          [-0.48431373, -0.48039216, -0.4882353 ],
#          [-0.47254902, -0.46862745, -0.47254902]]],
#
#
#        ...,
#
#
#        [[[-0.42156863, -0.44117647, -0.45294118],
#          [-0.4254902 , -0.44509804, -0.45686275],
#          [-0.44117647, -0.44509804, -0.45686275],
#          ...,
#          [-0.46078432, -0.46470588, -0.47254902],
#          [-0.45294118, -0.45686275, -0.46470588],
#          [-0.4490196 , -0.45294118, -0.46078432]],
#
#         [[-0.41764706, -0.4372549 , -0.4490196 ],
#          [-0.42156863, -0.4372549 , -0.4490196 ],
#          [-0.42941177, -0.43333334, -0.45294118],
#          ...,
#          [-0.46078432, -0.46470588, -0.47254902],
#          [-0.46078432, -0.46470588, -0.47254902],
#          [-0.45294118, -0.45686275, -0.46470588]],
#
#         [[-0.41764706, -0.4372549 , -0.4490196 ],
#          [-0.41764706, -0.43333334, -0.45294118],
#          [-0.42156863, -0.42941177, -0.45686275],
#          ...,
#          [-0.45294118, -0.45686275, -0.46470588],
#          [-0.45294118, -0.45686275, -0.46470588],
#          [-0.4490196 , -0.45294118, -0.46078432]],
#
#         ...,
#
#         [[-0.37058824, -0.4019608 , -0.4490196 ],
#          [-0.36666667, -0.39803922, -0.44117647],
#          [-0.36666667, -0.39803922, -0.44117647],
#          ...,
#          [-0.39019608, -0.4019608 , -0.29607844],
#          [-0.38627452, -0.4019608 , -0.27254903],
#          [-0.40980393, -0.42156863, -0.33529413]],
#
#         [[-0.37058824, -0.4019608 , -0.44509804],
#          [-0.36666667, -0.39803922, -0.44117647],
#          [-0.36666667, -0.39803922, -0.44117647],
#          ...,
#          [-0.39411765, -0.40588236, -0.29607844],
#          [-0.39411765, -0.40588236, -0.28039217],
#          [-0.4019608 , -0.4137255 , -0.3156863 ]],
#
#         [[-0.37843138, -0.40980393, -0.45294118],
#          [-0.3745098 , -0.40588236, -0.4490196 ],
#          [-0.37058824, -0.4019608 , -0.44509804],
#          ...,
#          [-0.40588236, -0.40980393, -0.30392158],
#          [-0.39803922, -0.40980393, -0.29215688],
#          [-0.4019608 , -0.42156863, -0.3156863 ]]],
#
#
#        [[[-0.4019608 , -0.34313726, -0.45294118],
#          [-0.44117647, -0.35882354, -0.4882353 ],
#          [-0.40980393, -0.3392157 , -0.42941177],
#          ...,
#          [-0.26078433, -0.17843136, -0.19411764],
#          [-0.13921568, -0.05686274, -0.06078431],
#          [-0.20588234, -0.15098038, -0.13921568]],
#
#         [[-0.45294118, -0.4019608 , -0.4764706 ],
#          [-0.42156863, -0.35490197, -0.47254902],
#          [-0.40588236, -0.35882354, -0.44117647],
#          ...,
#          [-0.0490196 ,  0.02549022,  0.0411765 ],
#          [ 0.08431375,  0.15882355,  0.19411767],
#          [-0.09215686, -0.04117647,  0.01372552]],
#
#         [[-0.45294118, -0.4019608 , -0.45686275],
#          [-0.44117647, -0.38627452, -0.4764706 ],
#          [-0.36666667, -0.34313726, -0.40588236],
#          ...,
#          [ 0.10392159,  0.17450982,  0.2137255 ],
#          [ 0.1156863 ,  0.18627453,  0.2529412 ],
#          [-0.04509804,  0.00588238,  0.09215689]],
#
#         ...,
#
#         [[-0.10784313,  0.00588238, -0.18235293],
#          [-0.09607843,  0.01764709, -0.17058823],
#          [-0.09215686,  0.02549022, -0.16274509],
#          ...,
#          [-0.11960784,  0.00196081, -0.17058823],
#          [-0.11568627, -0.00588235, -0.17058823],
#          [-0.14313725, -0.02549019, -0.19019607]],
#
#         [[-0.09607843,  0.01764709, -0.1745098 ],
#          [-0.09215686,  0.01372552, -0.1745098 ],
#          [-0.08039215,  0.02941179, -0.15882352],
#          ...,
#          [-0.10392156,  0.01764709, -0.15882352],
#          [-0.1117647 , -0.00196078, -0.17058823],
#          [-0.13921568, -0.02549019, -0.19019607]],
#
#         [[-0.12745097, -0.00588235, -0.19411764],
#          [-0.12745097, -0.01764706, -0.20196077],
#          [-0.10392156,  0.00196081, -0.18235293],
#          ...,
#          [-0.13529411, -0.01372549, -0.1862745 ],
#          [-0.12745097, -0.01764706, -0.18235293],
#          [-0.13921568, -0.02941176, -0.1862745 ]]],
#
#
#        [[[-0.21372548, -0.19411764, -0.20588234],
#          [-0.11568627, -0.09607843, -0.05686274],
#          [-0.1117647 , -0.08431372, -0.05294117],
#          ...,
#          [ 0.02941179,  0.08823532,  0.09607846],
#          [ 0.02941179,  0.08431375,  0.10392159],
#          [ 0.29607844,  0.34313726,  0.3745098 ]],
#
#         [[-0.22941175, -0.21372548, -0.22549018],
#          [-0.17058823, -0.15098038, -0.11960784],
#          [-0.23333332, -0.20588234, -0.18235293],
#          ...,
#          [-0.16666666, -0.12745097, -0.15098038],
#          [-0.22156861, -0.17843136, -0.1862745 ],
#          [-0.02941176,  0.02156866,  0.02941179]],
#
#         [[-0.22941175, -0.21372548, -0.22549018],
#          [-0.14705881, -0.12745097, -0.10784313],
#          [-0.25686276, -0.22156861, -0.20980391],
#          ...,
#          [-0.20980391, -0.18235293, -0.22549018],
#          [-0.29215688, -0.25686276, -0.2882353 ],
#          [-0.25686276, -0.20980391, -0.22941175]],
#
#         ...,
#
#         [[-0.01764706,  0.00196081, -0.1235294 ],
#          [ 0.01764709,  0.01764709, -0.09999999],
#          [ 0.00588238,  0.00196081, -0.10784313],
#          ...,
#          [-0.07647058, -0.08039215, -0.15490195],
#          [-0.25686276, -0.2647059 , -0.28431374],
#          [-0.39411765, -0.39411765, -0.39019608]],
#
#         [[-0.0490196 , -0.02549019, -0.14313725],
#          [-0.01764706, -0.01372549, -0.12745097],
#          [ 0.00588238, -0.00588235, -0.1117647 ],
#          ...,
#          [-0.0490196 , -0.04509804, -0.13137254],
#          [-0.24117646, -0.24509802, -0.26862746],
#          [-0.39411765, -0.39411765, -0.39411765]],
#
#         [[-0.04509804, -0.02941176, -0.14705881],
#          [-0.02549019, -0.02156863, -0.13137254],
#          [ 0.00588238,  0.00196081, -0.10392156],
#          ...,
#          [-0.04509804, -0.0490196 , -0.13137254],
#          [-0.23333332, -0.24509802, -0.27254903],
#          [-0.39411765, -0.39803922, -0.39803922]]]], dtype=float32)

# %%
dados[1]
# Out:
# array([[[[ 0.11960787, -0.06078431, -0.30784315],
#          [ 0.12352943, -0.06470588, -0.3156863 ],
#          [ 0.14705884, -0.04509804, -0.3       ],
#          ...,
#          [ 0.03725493, -0.12745097, -0.35882354],
#          [-0.00588235, -0.14313725, -0.35882354],
#          [-0.04509804, -0.16666666, -0.37058824]],
#
#         [[ 0.09607846, -0.06078431, -0.3       ],
#          [ 0.09215689, -0.06862745, -0.34313726],
#          [ 0.12352943, -0.05294117, -0.32352942],
#          ...,
#          [ 0.03333336, -0.12745097, -0.37843138],
#          [-0.00980392, -0.14313725, -0.3745098 ],
#          [-0.03333333, -0.15490195, -0.36666667]],
#
#         [[ 0.09215689, -0.06862745, -0.3156863 ],
#          [ 0.09215689, -0.07254902, -0.37058824],
#          [ 0.11960787, -0.06470588, -0.35882354],
#          ...,
#          [ 0.04509807, -0.11568627, -0.36666667],
#          [ 0.00980395, -0.12745097, -0.36666667],
#          [-0.02941176, -0.15098038, -0.37058824]],
#
#         ...,
#
#         [[-0.23333332, -0.01372549,  0.19411767],
#          [-0.33529413, -0.10784313,  0.08039218],
#          [-0.37843138, -0.15490195,  0.03725493],
#          ...,
#          [-0.3509804 , -0.11960784,  0.07254905],
#          [-0.4490196 , -0.2490196 , -0.07647058],
#          [-0.34313726, -0.16666666, -0.00196078]],
#
#         [[-0.26078433, -0.04509804,  0.15882355],
#          [-0.30784315, -0.09999999,  0.08039218],
#          [-0.3627451 , -0.16666666,  0.01764709],
#          ...,
#          [-0.39803922, -0.17843136,  0.00980395],
#          [-0.38627452, -0.17843136, -0.00588235],
#          [-0.42156863, -0.2490196 , -0.08039215]],
#
#         [[-0.2882353 , -0.08039215,  0.127451  ],
#          [-0.28039217, -0.08823529,  0.08431375],
#          [-0.32352942, -0.15098038,  0.01764709],
#          ...,
#          [-0.40588236, -0.1980392 , -0.01372549],
#          [-0.36666667, -0.17058823,  0.00588238],
#          [-0.41764706, -0.23725489, -0.06862745]]],
#
#
#        [[[ 0.42156863,  0.42156863,  0.42156863],
#          [ 0.40588236,  0.40588236,  0.40588236],
#          [ 0.40980393,  0.40980393,  0.40980393],
#          ...,
#          [ 0.4137255 ,  0.4137255 ,  0.4137255 ],
#          [ 0.4137255 ,  0.4137255 ,  0.4137255 ],
#          [ 0.40980393,  0.40980393,  0.40980393]],
#
#         [[ 0.43333334,  0.43333334,  0.43333334],
#          [ 0.42156863,  0.42156863,  0.42156863],
#          [ 0.42156863,  0.42156863,  0.42156863],
#          ...,
#          [ 0.4254902 ,  0.4254902 ,  0.4254902 ],
#          [ 0.4254902 ,  0.4254902 ,  0.4254902 ],
#          [ 0.42156863,  0.42156863,  0.42156863]],
#
#         [[ 0.42941177,  0.42941177,  0.42941177],
#          [ 0.41764706,  0.41764706,  0.41764706],
#          [ 0.41764706,  0.41764706,  0.41764706],
#          ...,
#          [ 0.42156863,  0.42156863,  0.42156863],
#          [ 0.42156863,  0.42156863,  0.42156863],
#          [ 0.41764706,  0.41764706,  0.41764706]],
#
#         ...,
#
#         [[-0.15882352, -0.1117647 , -0.15098038],
#          [-0.33137256, -0.3       , -0.35490197],
#          [-0.4254902 , -0.40980393, -0.45686275],
#          ...,
#          [ 0.16274512,  0.22156864,  0.2019608 ],
#          [ 0.2137255 ,  0.27254903,  0.25686276],
#          [ 0.23725492,  0.29215688,  0.2882353 ]],
#
#         [[-0.17843136, -0.1235294 , -0.17843136],
#          [-0.31960785, -0.2764706 , -0.35882354],
#          [-0.35882354, -0.327451  , -0.4137255 ],
#          ...,
#          [ 0.18235296,  0.24117649,  0.21764708],
#          [ 0.22549021,  0.28431374,  0.26862746],
#          [ 0.23333335,  0.29215688,  0.28431374]],
#
#         [[-0.16666666, -0.10392156, -0.1745098 ],
#          [-0.25686276, -0.20588234, -0.31176472],
#          [-0.27254903, -0.23725489, -0.3509804 ],
#          ...,
#          [ 0.15882355,  0.21764708,  0.19803923],
#          [ 0.20588237,  0.2647059 ,  0.24901962],
#          [ 0.22941178,  0.28431374,  0.28039217]]],
#
#
#        [[[ 0.11960787,  0.24509805,  0.37058824],
#          [ 0.11960787,  0.23333335,  0.35490197],
#          [ 0.04509807,  0.15098041,  0.26078433],
#          ...,
#          [ 0.39411765,  0.40588236,  0.41764706],
#          [ 0.42941177,  0.4372549 ,  0.45294118],
#          [ 0.43333334,  0.44509804,  0.46470588]],
#
#         [[ 0.16666669,  0.28431374,  0.39803922],
#          [ 0.17450982,  0.28039217,  0.38627452],
#          [ 0.09215689,  0.1901961 ,  0.2882353 ],
#          ...,
#          [ 0.40980393,  0.40980393,  0.4254902 ],
#          [ 0.46470588,  0.46470588,  0.48039216],
#          [ 0.46470588,  0.46862745,  0.48431373]],
#
#         [[ 0.18235296,  0.2882353 ,  0.38235295],
#          [ 0.1901961 ,  0.28431374,  0.37058824],
#          [ 0.1156863 ,  0.2019608 ,  0.28039217],
#          ...,
#          [ 0.4019608 ,  0.39803922,  0.40980393],
#          [ 0.48039216,  0.4764706 ,  0.48431373],
#          [ 0.46078432,  0.45686275,  0.46862745]],
#
#         ...,
#
#         [[-0.37843138, -0.34313726, -0.32352942],
#          [-0.38235295, -0.34705883, -0.327451  ],
#          [-0.39803922, -0.3627451 , -0.34313726],
#          ...,
#          [-0.35490197, -0.34313726, -0.31960785],
#          [-0.46470588, -0.4490196 , -0.44509804],
#          [-0.48431373, -0.47254902, -0.48039216]],
#
#         [[-0.40980393, -0.36666667, -0.34705883],
#          [-0.39411765, -0.3509804 , -0.33137256],
#          [-0.4019608 , -0.35882354, -0.3392157 ],
#          ...,
#          [-0.4254902 , -0.42156863, -0.40588236],
#          [-0.48431373, -0.4764706 , -0.4882353 ],
#          [-0.48039216, -0.47254902, -0.4882353 ]],
#
#         [[-0.39019608, -0.3392157 , -0.3156863 ],
#          [-0.38235295, -0.33137256, -0.30392158],
#          [-0.3745098 , -0.32352942, -0.29607844],
#          ...,
#          [-0.48039216, -0.4764706 , -0.46862745],
#          [-0.48431373, -0.48039216, -0.4882353 ],
#          [-0.47254902, -0.46862745, -0.47254902]]],
#
#
#        ...,
#
#
#        [[[-0.42156863, -0.44117647, -0.45294118],
#          [-0.4254902 , -0.44509804, -0.45686275],
#          [-0.44117647, -0.44509804, -0.45686275],
#          ...,
#          [-0.46078432, -0.46470588, -0.47254902],
#          [-0.45294118, -0.45686275, -0.46470588],
#          [-0.4490196 , -0.45294118, -0.46078432]],
#
#         [[-0.41764706, -0.4372549 , -0.4490196 ],
#          [-0.42156863, -0.4372549 , -0.4490196 ],
#          [-0.42941177, -0.43333334, -0.45294118],
#          ...,
#          [-0.46078432, -0.46470588, -0.47254902],
#          [-0.46078432, -0.46470588, -0.47254902],
#          [-0.45294118, -0.45686275, -0.46470588]],
#
#         [[-0.41764706, -0.4372549 , -0.4490196 ],
#          [-0.41764706, -0.43333334, -0.45294118],
#          [-0.42156863, -0.42941177, -0.45686275],
#          ...,
#          [-0.45294118, -0.45686275, -0.46470588],
#          [-0.45294118, -0.45686275, -0.46470588],
#          [-0.4490196 , -0.45294118, -0.46078432]],
#
#         ...,
#
#         [[-0.37058824, -0.4019608 , -0.4490196 ],
#          [-0.36666667, -0.39803922, -0.44117647],
#          [-0.36666667, -0.39803922, -0.44117647],
#          ...,
#          [-0.39019608, -0.4019608 , -0.29607844],
#          [-0.38627452, -0.4019608 , -0.27254903],
#          [-0.40980393, -0.42156863, -0.33529413]],
#
#         [[-0.37058824, -0.4019608 , -0.44509804],
#          [-0.36666667, -0.39803922, -0.44117647],
#          [-0.36666667, -0.39803922, -0.44117647],
#          ...,
#          [-0.39411765, -0.40588236, -0.29607844],
#          [-0.39411765, -0.40588236, -0.28039217],
#          [-0.4019608 , -0.4137255 , -0.3156863 ]],
#
#         [[-0.37843138, -0.40980393, -0.45294118],
#          [-0.3745098 , -0.40588236, -0.4490196 ],
#          [-0.37058824, -0.4019608 , -0.44509804],
#          ...,
#          [-0.40588236, -0.40980393, -0.30392158],
#          [-0.39803922, -0.40980393, -0.29215688],
#          [-0.4019608 , -0.42156863, -0.3156863 ]]],
#
#
#        [[[-0.4019608 , -0.34313726, -0.45294118],
#          [-0.44117647, -0.35882354, -0.4882353 ],
#          [-0.40980393, -0.3392157 , -0.42941177],
#          ...,
#          [-0.26078433, -0.17843136, -0.19411764],
#          [-0.13921568, -0.05686274, -0.06078431],
#          [-0.20588234, -0.15098038, -0.13921568]],
#
#         [[-0.45294118, -0.4019608 , -0.4764706 ],
#          [-0.42156863, -0.35490197, -0.47254902],
#          [-0.40588236, -0.35882354, -0.44117647],
#          ...,
#          [-0.0490196 ,  0.02549022,  0.0411765 ],
#          [ 0.08431375,  0.15882355,  0.19411767],
#          [-0.09215686, -0.04117647,  0.01372552]],
#
#         [[-0.45294118, -0.4019608 , -0.45686275],
#          [-0.44117647, -0.38627452, -0.4764706 ],
#          [-0.36666667, -0.34313726, -0.40588236],
#          ...,
#          [ 0.10392159,  0.17450982,  0.2137255 ],
#          [ 0.1156863 ,  0.18627453,  0.2529412 ],
#          [-0.04509804,  0.00588238,  0.09215689]],
#
#         ...,
#
#         [[-0.10784313,  0.00588238, -0.18235293],
#          [-0.09607843,  0.01764709, -0.17058823],
#          [-0.09215686,  0.02549022, -0.16274509],
#          ...,
#          [-0.11960784,  0.00196081, -0.17058823],
#          [-0.11568627, -0.00588235, -0.17058823],
#          [-0.14313725, -0.02549019, -0.19019607]],
#
#         [[-0.09607843,  0.01764709, -0.1745098 ],
#          [-0.09215686,  0.01372552, -0.1745098 ],
#          [-0.08039215,  0.02941179, -0.15882352],
#          ...,
#          [-0.10392156,  0.01764709, -0.15882352],
#          [-0.1117647 , -0.00196078, -0.17058823],
#          [-0.13921568, -0.02549019, -0.19019607]],
#
#         [[-0.12745097, -0.00588235, -0.19411764],
#          [-0.12745097, -0.01764706, -0.20196077],
#          [-0.10392156,  0.00196081, -0.18235293],
#          ...,
#          [-0.13529411, -0.01372549, -0.1862745 ],
#          [-0.12745097, -0.01764706, -0.18235293],
#          [-0.13921568, -0.02941176, -0.1862745 ]]],
#
#
#        [[[-0.21372548, -0.19411764, -0.20588234],
#          [-0.11568627, -0.09607843, -0.05686274],
#          [-0.1117647 , -0.08431372, -0.05294117],
#          ...,
#          [ 0.02941179,  0.08823532,  0.09607846],
#          [ 0.02941179,  0.08431375,  0.10392159],
#          [ 0.29607844,  0.34313726,  0.3745098 ]],
#
#         [[-0.22941175, -0.21372548, -0.22549018],
#          [-0.17058823, -0.15098038, -0.11960784],
#          [-0.23333332, -0.20588234, -0.18235293],
#          ...,
#          [-0.16666666, -0.12745097, -0.15098038],
#          [-0.22156861, -0.17843136, -0.1862745 ],
#          [-0.02941176,  0.02156866,  0.02941179]],
#
#         [[-0.22941175, -0.21372548, -0.22549018],
#          [-0.14705881, -0.12745097, -0.10784313],
#          [-0.25686276, -0.22156861, -0.20980391],
#          ...,
#          [-0.20980391, -0.18235293, -0.22549018],
#          [-0.29215688, -0.25686276, -0.2882353 ],
#          [-0.25686276, -0.20980391, -0.22941175]],
#
#         ...,
#
#         [[-0.01764706,  0.00196081, -0.1235294 ],
#          [ 0.01764709,  0.01764709, -0.09999999],
#          [ 0.00588238,  0.00196081, -0.10784313],
#          ...,
#          [-0.07647058, -0.08039215, -0.15490195],
#          [-0.25686276, -0.2647059 , -0.28431374],
#          [-0.39411765, -0.39411765, -0.39019608]],
#
#         [[-0.0490196 , -0.02549019, -0.14313725],
#          [-0.01764706, -0.01372549, -0.12745097],
#          [ 0.00588238, -0.00588235, -0.1117647 ],
#          ...,
#          [-0.0490196 , -0.04509804, -0.13137254],
#          [-0.24117646, -0.24509802, -0.26862746],
#          [-0.39411765, -0.39411765, -0.39411765]],
#
#         [[-0.04509804, -0.02941176, -0.14705881],
#          [-0.02549019, -0.02156863, -0.13137254],
#          [ 0.00588238,  0.00196081, -0.10392156],
#          ...,
#          [-0.04509804, -0.0490196 , -0.13137254],
#          [-0.23333332, -0.24509802, -0.27254903],
#          [-0.39411765, -0.39803922, -0.39803922]]]], dtype=float32)
